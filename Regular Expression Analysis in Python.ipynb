# %%
import re
import ast

regular_expression1 = "a+c*(b*c)"

regular_expression2 = "5+2*(5*2)"
def lexical_analyzer():
  lexical_analyzer1 = re.findall(r"[.\()\*\w+]", regular_expression1)
def syntax_tree():
  syntax_tree1 = re.findall(r"[.\()\*\w+]", regular_expression2)

  syntax_tree = ast.parse("print(5+2*(5*2))")
  print(ast.dump(syntax_tree))
  exec(compile(syntax_tree, filename="", mode="exec"))

  syntax_tree_2 = ast.parse("print('a+c*(b*c)')")
  print(ast.dump(syntax_tree_2))
  exec(compile(syntax_tree_2, filename="", mode="exec"))
lexical_analyzer();
syntax_tree();
print(lexical_analyzer1)
print(syntax_tree1)
# Out:
# Module(body=[Expr(value=Call(func=Name(id='print', ctx=Load()), args=[BinOp(left=Constant(value=5, kind=None), op=Add(), right=BinOp(left=Constant(value=2, kind=None), op=Mult(), right=BinOp(left=Constant(value=5, kind=None), op=Mult(), right=Constant(value=2, kind=None))))], keywords=[]))], type_ignores=[])
# 25
# Module(body=[Expr(value=Call(func=Name(id='print', ctx=Load()), args=[Constant(value='a+c*(b*c)', kind=None)], keywords=[]))], type_ignores=[])
# a+c*(b*c)
# ['a', '+', 'c', '*', '(', 'b', '*', 'c', ')']
# ['5', '+', '2', '*', '(', '5', '*', '2', ')']
